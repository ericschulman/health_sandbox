# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Read and merge Census

# %%
data_path = "../data/data_2016/"
acs1 = pd.read_csv(data_path + 'ACSDP5Y2016.DP03_data_with_overlays_2022-03-17T201553.csv', na_values=['(X)']) #, encoding='cp1252'
acs2 = pd.read_csv(data_path + 'ACSDP5Y2016.DP05_data_with_overlays_2021-12-09T232536.csv', na_values=['(X)']) 
acs3 = pd.read_csv(data_path + 'ACSST5Y2016.S1701_data_with_overlays_2021-12-12T065723.csv', na_values=['(X)'])

#DP03_0095E - health care coverage

def remove_cols(df):
    
    #save county
    county = df['GEO_ID']
    county = county.str[-5:]
    county = county.astype(str) 
    county = county.loc[1:]
    
    #find the bad columns
    cols = list(df.columns)
    trim_cols1 = []
    for col in cols:
        income_col = 'C01_' in col and 'E' in col
        if 'PE' in col or 'DP03_0095E' in col or income_col:
            trim_cols1.append(col)

    df = df[trim_cols1]
    df = df.loc[1:]
    df.fillna(0, inplace = True)
    
    
    #filter out bad columns
    df['County'] = county
    
    return df


dfs = []

for i in [acs1,acs2,acs3]:
    dfs.append(remove_cols(i))

for i in dfs:
    print(i.shape)
# Out:
# (3220, 139)
# (3220, 85)
# (3220, 62)

# %%
from functools import partial, reduce
[acs1, acs2,acs3] = dfs
merge = partial(pd.merge, on=['County'], how='outer')
all_acs = reduce(merge, dfs)
all_acs
# Out:
#      DP03_0001PE DP03_0002PE DP03_0003PE DP03_0004PE DP03_0005PE DP03_0006PE  \
# 0          42712        60.9        60.2        56.8         3.4         0.7
# 1         160301        58.6        58.4        54.7         3.7         0.1
# 2          21476        48.0        48.0        41.9         6.2         0.0
# 3          18496        48.7        48.6        45.2         3.5         0.0
# 4          46007        49.9        49.9        46.9         3.0         0.0
# ...          ...         ...         ...         ...         ...         ...
# 3215       45100        37.8        37.8        31.2         6.5         0.0
# 3216        7229        46.2        46.2        40.6         5.7         0.0
# 3217       19212        48.3        48.2        36.2        12.0         0.1
# 3218       28916        37.4        37.3        28.3         9.0         0.1
# 3219       31386        38.0        38.0        28.8         9.1         0.1
#
#      DP03_0007PE DP03_0008PE DP03_0009PE DP03_0010PE  ... S1701_C01_052E  \
# 0           39.1       25699         5.6       22074  ...            952
# 1           41.4       93640         6.3       82813  ...           4493
# 2           52.0       10316        12.8        9938  ...            651
# 3           51.3        8997         7.1        8514  ...            294
# 4           50.1       22960         6.0       23370  ...            894
# ...          ...         ...         ...         ...  ...            ...
# 3215        62.2       17037        17.3       23837  ...            639
# 3216        53.8        3342        12.3        3622  ...             41
# 3217        51.7        9256        24.8        9970  ...            430
# 3218        62.6       10778        24.2       15074  ...            513
# 3219        62.0       11913        24.0       16546  ...            281
#
#      S1701_C01_053E S1701_C01_054E S1701_C01_055E S1701_C01_056E  \
# 0               860           1467           1336           1152
# 1              3936           5446           6397           5225
# 2               364            606            655            733
# 3               308            561            323            484
# 4               704           1072           1267           1257
# ...             ...            ...            ...            ...
# 3215            757           1138           1288           1379
# 3216            230            273            319            374
# 3217            303            470            496            547
# 3218            857            961           1249           1165
# 3219            439            433           1233           1036
#
#      S1701_C01_057E S1701_C01_058E S1701_C01_059E S1701_C01_060E  \
# 0              1091           5417           3374           1132
# 1              5209           6288          12802           6793
# 2               674           5349           1274            621
# 3               380           7539            742            317
# 4              1215           6610           2121           1007
# ...             ...            ...            ...            ...
# 3215           1140           7833           1374            483
# 3216            232           6304            495            251
# 3217            319           7023            489            531
# 3218            661           7824            937            418
# 3219            823           7493            555            414
#
#      S1701_C01_061E
# 0              3316
# 1             14202
# 2              1993
# 3              1504
# 4              3631
# ...             ...
# 3215           4669
# 3216            751
# 3217           1656
# 3218           4391
# 3219           3473
#
# [3220 rows x 284 columns]

# %% [markdown]
# # Preprocess CSR

# %%
csr = pd.read_csv(data_path + 'csrzipcounty2016.csv', na_values=['.'])
csr.columns = csr.iloc[2]
csr = csr.iloc[4:-1]
csr.reset_index(drop=True)
csr
# Out:
# 2    State FIPS County Code          County Name Total Number of Consumers  \
# 4       AK            02013       ALEUTIANS EAST                        38
# 5       AK            02016       ALEUTIANS WEST                        38
# 6       AK            02020            ANCHORAGE                     9,484
# 7       AK            02050               BETHEL                        73
# 8       AK            02060  BRISTOL BAY BOROUGH                        34
# ...    ...              ...                  ...                       ...
# 2600    WY            56037           SWEETWATER                     1,168
# 2601    WY            56039                TETON                     2,812
# 2602    WY            56041                UINTA                       663
# 2603    WY            56043             WASHAKIE                       341
# 2604    WY            56045               WESTON                       237
#
# 2    Number of Consumers with CSR (AV of 73%/87%/94%)  \
# 4                                                  16
# 5                                                  16
# 6                                               3,917
# 7                                                  18
# 8                                                  12
# ...                                               ...
# 2600                                              665
# 2601                                            1,411
# 2602                                              356
# 2603                                              173
# 2604                                              112
#
# 2    Number of Consumers with CSR AV of 73%  \
# 4                                       NaN
# 5                                       NaN
# 6                                       787
# 7                                       NaN
# 8                                       NaN
# ...                                     ...
# 2600                                    109
# 2601                                    428
# 2602                                     79
# 2603                                     33
# 2604                                     26
#
# 2    Number of Consumers with CSR AV of 87%  \
# 4                                       NaN
# 5                                       NaN
# 6                                     1,640
# 7                                        11
# 8                                       NaN
# ...                                     ...
# 2600                                    222
# 2601                                    484
# 2602                                    116
# 2603                                     54
# 2604                                     24
#
# 2    Number of Consumers with CSR AV of 94%  \
# 4                                       NaN
# 5                                       NaN
# 6                                     1,490
# 7                                       NaN
# 8                                       NaN
# ...                                     ...
# 2600                                    334
# 2601                                    499
# 2602                                    161
# 2603                                     86
# 2604                                     62
#
# 2    Average Monthly Advanced CSR Payment for Consumers with 73%  \
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   $26
# 7                                                   NaN
# 8                                                   NaN
# ...                                                 ...
# 2600                                                $16
# 2601                                                $15
# 2602                                                $16
# 2603                                                $15
# 2604                                                $25
#
# 2    Average Monthly Advanced CSR Payment for Consumers with 87%  \
# 4                                                   NaN
# 5                                                   NaN
# 6                                                  $204
# 7                                                  $234
# 8                                                   NaN
# ...                                                 ...
# 2600                                               $119
# 2601                                               $115
# 2602                                               $133
# 2603                                               $138
# 2604                                               $170
#
# 2    Average Monthly Advanced CSR Payment for Consumers with 94%
# 4                                                   NaN
# 5                                                   NaN
# 6                                                  $290
# 7                                                   NaN
# 8                                                   NaN
# ...                                                 ...
# 2600                                               $173
# 2601                                               $165
# 2602                                               $181
# 2603                                               $192
# 2604                                               $191
#
# [2601 rows x 11 columns]

# %%
csr_clean = csr.copy()
csr_clean = csr_clean
for column in list(csr.columns)[3:]:
    csr_clean[column] = csr_clean[column].fillna('0')
    csr_clean[column] = csr_clean[column].apply(lambda x: float((str(x)).replace('$','').replace(',','')) )

# %%
merged_acs = all_acs.merge(csr_clean, how='left', left_on='County', right_on='FIPS County Code')
merged_acs
# Out:
#      DP03_0001PE DP03_0002PE DP03_0003PE DP03_0004PE DP03_0005PE DP03_0006PE  \
# 0          42712        60.9        60.2        56.8         3.4         0.7
# 1         160301        58.6        58.4        54.7         3.7         0.1
# 2          21476        48.0        48.0        41.9         6.2         0.0
# 3          18496        48.7        48.6        45.2         3.5         0.0
# 4          46007        49.9        49.9        46.9         3.0         0.0
# ...          ...         ...         ...         ...         ...         ...
# 3215       45100        37.8        37.8        31.2         6.5         0.0
# 3216        7229        46.2        46.2        40.6         5.7         0.0
# 3217       19212        48.3        48.2        36.2        12.0         0.1
# 3218       28916        37.4        37.3        28.3         9.0         0.1
# 3219       31386        38.0        38.0        28.8         9.1         0.1
#
#      DP03_0007PE DP03_0008PE DP03_0009PE DP03_0010PE  ... FIPS County Code  \
# 0           39.1       25699         5.6       22074  ...            01001
# 1           41.4       93640         6.3       82813  ...            01003
# 2           52.0       10316        12.8        9938  ...            01005
# 3           51.3        8997         7.1        8514  ...            01007
# 4           50.1       22960         6.0       23370  ...            01009
# ...          ...         ...         ...         ...  ...              ...
# 3215        62.2       17037        17.3       23837  ...              NaN
# 3216        53.8        3342        12.3        3622  ...              NaN
# 3217        51.7        9256        24.8        9970  ...              NaN
# 3218        62.6       10778        24.2       15074  ...              NaN
# 3219        62.0       11913        24.0       16546  ...              NaN
#
#      County Name Total Number of Consumers  \
# 0        AUTAUGA                    1896.0
# 1        BALDWIN                   11778.0
# 2        BARBOUR                     801.0
# 3           BIBB                     629.0
# 4         BLOUNT                    2264.0
# ...          ...                       ...
# 3215         NaN                       NaN
# 3216         NaN                       NaN
# 3217         NaN                       NaN
# 3218         NaN                       NaN
# 3219         NaN                       NaN
#
#      Number of Consumers with CSR (AV of 73%/87%/94%)  \
# 0                                              1341.0
# 1                                              8342.0
# 2                                               584.0
# 3                                               477.0
# 4                                              1663.0
# ...                                               ...
# 3215                                              NaN
# 3216                                              NaN
# 3217                                              NaN
# 3218                                              NaN
# 3219                                              NaN
#
#      Number of Consumers with CSR AV of 73%  \
# 0                                     142.0
# 1                                    1246.0
# 2                                      62.0
# 3                                      58.0
# 4                                     197.0
# ...                                     ...
# 3215                                    NaN
# 3216                                    NaN
# 3217                                    NaN
# 3218                                    NaN
# 3219                                    NaN
#
#      Number of Consumers with CSR AV of 87%  \
# 0                                     399.0
# 1                                    2426.0
# 2                                     155.0
# 3                                     121.0
# 4                                     437.0
# ...                                     ...
# 3215                                    NaN
# 3216                                    NaN
# 3217                                    NaN
# 3218                                    NaN
# 3219                                    NaN
#
#      Number of Consumers with CSR AV of 94%  \
# 0                                     800.0
# 1                                    4670.0
# 2                                     367.0
# 3                                     298.0
# 4                                    1029.0
# ...                                     ...
# 3215                                    NaN
# 3216                                    NaN
# 3217                                    NaN
# 3218                                    NaN
# 3219                                    NaN
#
#      Average Monthly Advanced CSR Payment for Consumers with 73%  \
# 0                                                  13.0
# 1                                                  13.0
# 2                                                  13.0
# 3                                                  15.0
# 4                                                  14.0
# ...                                                 ...
# 3215                                                NaN
# 3216                                                NaN
# 3217                                                NaN
# 3218                                                NaN
# 3219                                                NaN
#
#      Average Monthly Advanced CSR Payment for Consumers with 87%  \
# 0                                                  87.0
# 1                                                  91.0
# 2                                                  98.0
# 3                                                 101.0
# 4                                                  96.0
# ...                                                 ...
# 3215                                                NaN
# 3216                                                NaN
# 3217                                                NaN
# 3218                                                NaN
# 3219                                                NaN
#
#      Average Monthly Advanced CSR Payment for Consumers with 94%
# 0                                                 117.0
# 1                                                 121.0
# 2                                                 132.0
# 3                                                 123.0
# 4                                                 132.0
# ...                                                 ...
# 3215                                                NaN
# 3216                                                NaN
# 3217                                                NaN
# 3218                                                NaN
# 3219                                                NaN
#
# [3220 rows x 295 columns]

# %%
missing_value_df = pd.DataFrame(merged_acs.isnull().sum())
missing_value_df.T #= missing_value_df.T
#all_merged = pd.concat([merged_acs, missing_value_df])
# Out:
#    DP03_0001PE  DP03_0002PE  DP03_0003PE  DP03_0004PE  DP03_0005PE  \
# 0            0            0            0            0            0
#
#    DP03_0006PE  DP03_0007PE  DP03_0008PE  DP03_0009PE  DP03_0010PE  ...  \
# 0            0            0            0            0            0  ...
#
#    FIPS County Code  County Name  Total Number of Consumers  \
# 0               622          622                        622
#
#    Number of Consumers with CSR (AV of 73%/87%/94%)  \
# 0                                               622
#
#    Number of Consumers with CSR AV of 73%  \
# 0                                     622
#
#    Number of Consumers with CSR AV of 87%  \
# 0                                     622
#
#    Number of Consumers with CSR AV of 94%  \
# 0                                     622
#
#    Average Monthly Advanced CSR Payment for Consumers with 73%  \
# 0                                                622
#
#    Average Monthly Advanced CSR Payment for Consumers with 87%  \
# 0                                                622
#
#    Average Monthly Advanced CSR Payment for Consumers with 94%
# 0                                                622
#
# [1 rows x 295 columns]

# %%
merged_acs.fillna(0, inplace = True)
merged_acs.to_csv('../data/processed_data/county_characteristics.csv', index=False)
